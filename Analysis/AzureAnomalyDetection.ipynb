# %%
import os
import time
from datetime import datetime

import pandas as pd
import pyodbc
import urllib

from azure.ai.anomalydetector import AnomalyDetectorClient
from azure.ai.anomalydetector.models import DetectionRequest, ModelInfo
from azure.core.credentials import AzureKeyCredential
from azure.core.exceptions import HttpResponseError

# %%
SUBSCRIPTION_KEY = os.environ["ANOMALY_DETECTOR_KEY"]
ANOMALY_DETECTOR_ENDPOINT = os.environ["ANOMALY_DETECTOR_ENDPOINT"]
TIME_SERIES_DATA_PATH = os.path.join("./sample_data", "request-data.csv")

# %% [markdown]
# # Prepare the data

# %%
def get_data_hack(sql):
    con=pyodbc.connect("Driver={SQL Server Native Client 11.0};"
                           "Server={};"
                           "Database={};"
                           "uid={};"
                           "pwd={};")
    df=pd.read_sql(sql,con)
    con.close()
    return df

# %%
def saveSqlAsFiles(sql, FolderName = 'AzureBlobMinute'):
    df2 = get_data_hack(sql)
    df2['data'] = pd.to_datetime(df2.Dat).dt.tz_localize(None)
    df2 = df2.sort_values(by=['data'])
    df2.reset_index(inplace = True)
    
    for file in df2.TagName.unique():
        path = os.path.join("./"+FolderName, file.replace("/", "_") +".csv")
        tempdf = df2[df2.TagName == file]
        tempdf = tempdf[['Dat', 'MeanValue']]
        tempdf.rename(columns={'Dat':'timestamp','MeanValue':'value'}).to_csv(path, index=False)
    print("Data loaded into files")

# %%
def saveSqlAsFiles2(sql, file = 'Default', FolderName = 'AzureBlobOrgin'):
    df2 = get_data_hack(sql)
    df2['timestamp'] = df2.timestampCol.map(lambda x: datetime.strftime(x, '%Y-%m-%dT%H:%M:%SZ'))
    df2 = df2[['timestamp','value']]
    path = os.path.join("./"+FolderName, file.replace("/", "_") +".csv")
    df2.to_csv(path, index=False)
    print("Data loaded into files")

# %%
def saveDataFraneAsFiles(df2, FolderName = 'AzureBlobByDay'):
    df2['data'] = pd.to_datetime(df2.Dat).dt.tz_localize(None)
    df2 = df2.sort_values(by=['data'])
    df2.reset_index(inplace = True)
    
    for file in df2.TagName.unique():
        path = os.path.join("./"+FolderName, file.replace("/", "_") +".csv")
        tempdf = df2[df2.TagName == file]
        tempdf = tempdf[['Dat', 'MeanValue']]
        tempdf.rename(columns={'Dat':'timestamp','MeanValue':'value'}).to_csv(path, index=False)

# %% [markdown]
# ## Data by Day

# %%
sql2 = '''
  select 
  cast(Year as varchar)+'-'+cast(Month as varchar)+'-'+cast(Day as varchar)+'T'+cast(Hour as varchar)+':'+'00:00Z' Dat, 
  [TagName], MeanValue from (
  select 
	 
	DATEPART(YEAR, [DateTime]) Year,
	case when DATEPART(MONTH, [DateTime]) < 10 
	then '0'+cast(DATEPART(MONTH, [DateTime]) as varchar)
	else cast(DATEPART(MONTH, [DateTime]) as varchar)
	end Month,
	case when DATEPART(Day, [DateTime]) < 10 
	then '0'+cast(DATEPART(Day, [DateTime]) as varchar)
	else cast(DATEPART(Day, [DateTime]) as varchar)
	end Day,
	case when DATEPART(Hour, [DateTime]) < 10 
	then '0'+cast(DATEPART(Hour, [DateTime]) as varchar)
	else cast(DATEPART(Hour, [DateTime]) as varchar)
	end Hour,
	--DATEPART(DAY, [DateTime]) Day,
	--DATEPART(HOUR, [DateTime]) Hour,
	[TagName],
	avg(Value) MeanValue
	
  from 
	  --(select top (100000) * from 
	  [Hack_Data]
	  --) t1
  group by  
	DATEPART(YEAR, [DateTime]),
	DATEPART(MONTH, [DateTime]),
	DATEPART(DAY, [DateTime]),
	DATEPART(HOUR, [DateTime]),
    
	[TagName] 
) t1
'''

# %%
# %%time
df2 = get_data_hack(sql2)
# Out:
# Wall time: 1min 56s

# %%
df2
# Out:
#                          Dat                             TagName    MeanValue
# 0       2020-12-13T10:00:00Z                   T1_podc-kolektorP     7.829622
# 1       2020-11-22T20:00:00Z               T1_Wapno_PrzeplywWody     5.327799
# 2       2020-12-14T16:00:00Z                         T1_wydWaga6     2.136787
# 3       2020-12-16T03:00:00Z                        T1_tempPieca  1191.240278
# 4       2020-11-17T21:00:00Z  ssawa2_T480t2_temp_w_loz_B_silnika    35.646389
# ...                      ...                                 ...          ...
# 508702  2020-02-18T12:00:00Z                        T1_tempPieca   751.737705
# 508703  2020-11-26T02:00:00Z   ssawa1_T480t2_temp_w_lozB_silnika    61.726111
# 508704  2020-08-31T14:00:00Z     Ssawa2_Podcisnienie_przed_ssawa    12.188533
# 508705  2020-11-04T01:00:00Z      ssawa2_T559tD_temp_w_lozysku_D    52.562082
# 508706  2020-12-17T06:00:00Z                    T1_CO_na_chlodni    29.709201
#
# [508707 rows x 3 columns]

# %%
df2['data'] = pd.to_datetime(df2.Dat).dt.tz_localize(None)

# %%
df2 = df2.sort_values(by=['data'])

# %%
df2.reset_index(inplace = True)

# %%
# %%time
for file in df2.TagName.unique():
    path = os.path.join("./AzureBlob", file.replace("/", "_") +".csv")
    tempdf = df2[df2.TagName == file]
    tempdf = tempdf[['Dat', 'MeanValue']]
    tempdf.rename(columns={'Dat':'timestamp','MeanValue':'value'}).to_csv(path, index=False)
# Out:
# Wall time: 16 s

# %% [markdown]
# ## Data by Minute

# %%
sql1 = '''
  select 
  cast(Year as varchar)+'-'+cast(Month as varchar)+'-'+cast(Day as varchar)+'T'+cast(Hour as varchar)+':'+cast(Minute as varchar)+':00Z' Dat, 
  [TagName], MeanValue from (
  select 
	 
	DATEPART(YEAR, [DateTime]) Year,
	case when DATEPART(MONTH, [DateTime]) < 10 
	then '0'+cast(DATEPART(MONTH, [DateTime]) as varchar)
	else cast(DATEPART(MONTH, [DateTime]) as varchar)
	end Month,
	case when DATEPART(Day, [DateTime]) < 10 
	then '0'+cast(DATEPART(Day, [DateTime]) as varchar)
	else cast(DATEPART(Day, [DateTime]) as varchar)
	end Day,
	case when DATEPART(Hour, [DateTime]) < 10 
	then '0'+cast(DATEPART(Hour, [DateTime]) as varchar)
	else cast(DATEPART(Hour, [DateTime]) as varchar)
	end Hour,
    case when DATEPART(Minute, [DateTime]) < 10 
	then '0'+cast(DATEPART(Minute, [DateTime]) as varchar)
	else cast(DATEPART(Minute, [DateTime]) as varchar)
	end Minute,
	--DATEPART(DAY, [DateTime]) Day,
	--DATEPART(HOUR, [DateTime]) Hour,
	[TagName],
	avg(Value) MeanValue
	
  from 
	  --(select top (100000) * from 
	  [Hack_Data]
	  --) t1
  group by  
	DATEPART(YEAR, [DateTime]),
	DATEPART(MONTH, [DateTime]),
	DATEPART(DAY, [DateTime]),
	DATEPART(HOUR, [DateTime]),
    DATEPART(Minute, [DateTime]),
	[TagName] 
) t1
'''

# %%
# %%time
df1 = get_data_hack(sql1)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-3-52d2f80b4685> in get_data_hack(sql)
#       1 def get_data_hack(sql):
# ----> 2     con=pyodbc.connect("Driver={SQL Server Native Client 11.0};"
#       3                            "Server=ZHK-SQL-DB01.ispatcee.com;"
#       4                            "Database=HackDB;"
#       5                            "uid=extreader;"
#
# OperationalError: ('08001', '[08001] [Microsoft][SQL Server Native Client 11.0]Named Pipes Provider: Could not open a connection to SQL Server [53].  (53) (SQLDriverConnect); [08001] [Microsoft][SQL Server Native Client 11.0]Login timeout expired (0); [08001] [Microsoft][SQL Server Native Client 11.0]A network-related or instance-specific error has occurred while establishing a connection to SQL Server. Server is not found or not accessible. Check if instance name is correct and if SQL Server is configured to allow remote connections. For more information see SQL Server Books Online. (53)')

# %%
# %%time
saveSqlAsFiles(sql1)
# Out:
# Data loaded into files
# Wall time: 1h 52min 19s

# %%
# %%time
sql = """SELECT DISTINCT TagName from Hack_Data"""
df = get_data_hack(sql)
df
# Out:
# Wall time: 57.5 s
#                               TagName
# 0                         HF1_Delta_P
# 1             HF1_MonitSpalin_HF1_NOx
# 2              HF1_MonitSpalin_HF1_O2
# 3        HF1_MonitSpalin_HF1_Przeplyw
# 4             HF1_MonitSpalin_HF1_Pyl
# ..                                ...
# 160                       T1_wydWaga8
# 161                       T1_wydWaga9
# 162                T1_ZB7_zapelnienie
# 163  T1_ZBBufor_Sortownia_zapelnienie
# 164                  T1_ZBPods_ciezar
#
# [165 rows x 1 columns]

# %%
# %%time
#a = ['T1_ZBPods_ciezar']
for tag in df.TagName:
    print(tag)
    sql2 = """
    SELECT 
    [DateTime]as timestampCol,
    [Value] as value
    from
    Hack_Data
    where TagName = '{}'
    order by DateTime
    """.format(tag)
    saveSqlAsFiles2(sql2, tag)
# Out:
# HF1_Delta_P
# Data loaded into files
# HF1_MonitSpalin_HF1_NOx
# Data loaded into files
# HF1_MonitSpalin_HF1_O2
# Data loaded into files
# HF1_MonitSpalin_HF1_Przeplyw
# Data loaded into files
# HF1_MonitSpalin_HF1_Pyl
# Data loaded into files
# HF1_MonitSpalin_HF1_SO2
# Data loaded into files
# HF1A_Delta_P
# Data loaded into files
# HF1A_MonitSpalin_HF1A_NOx
# Data loaded into files
# HF1A_MonitSpalin_HF1A_O2
# Data loaded into files
# HF1A_MonitSpalin_HF1A_Przeplyw
# Data loaded into files
# HF1A_MonitSpalin_HF1A_Pyl
# Data loaded into files
# HF1A_MonitSpalin_HF1A_SO2
# Data loaded into files
# Kalor_gaz_opal_piec_zapl
# Data loaded into files
# PT32_wydajnosc
# Data loaded into files
# PT35_wydajnosc
# Data loaded into files
# ssawa1_F561t_przep_ol_w_lozyskuD
# Data loaded into files
# ssawa1_F562t_przep_ol_w_lozyskuC
# Data loaded into files
# ssawa1_F563/1t_przep_ol_w_lozB_si
# Data loaded into files
# ssawa1_F563/2t_przep_ol_w_lozA_si
# Data loaded into files
# ssawa1_otwarcie_klapy
# Data loaded into files
# ssawa1_P521C_cis_oleju_lozyskC
# Data loaded into files
# ssawa1_P521D_cis_oleju_lozyskD
# Data loaded into files
# ssawa1_P556a_cisn_oleju_wobiegu
# Data loaded into files
# Ssawa1_Podcisnienie_przed_ssawa
# Data loaded into files
# ssawa1_prad_silnika
# Data loaded into files
# ssawa1_prad_wzbudzenia
# Data loaded into files
# ssawa1_T480t1_temp_w_lozA_silnika
# Data loaded into files
# ssawa1_T480t2_temp_w_lozB_silnika
# Data loaded into files
# ssawa1_T480t3_temp_pow_chlsilwlot
# Data loaded into files
# ssawa1_T480t4_temp_pow_chlsilwlot
# Data loaded into files
# ssawa1_T480t5_temp_pow_chlsilwylo
# Data loaded into files
# ssawa1_T480t6_temp_pow_chlsilwylo
# Data loaded into files
# ssawa1_T480t7_temp_wody_chl_zasil
# Data loaded into files
# ssawa1_T480t8_temp_wody_chl_powro
# Data loaded into files
# ssawa1_T552_temp_oleju_wzb
# Data loaded into files
# ssawa1_T558t_temp_oleju_wobiegu
# Data loaded into files
# ssawa1_T559tC_temp_w_lozyskuC
# Data loaded into files
# ssawa1_T559tD_temp_w_lozyskuD
# Data loaded into files
# ssawa1_Temp_silnika_miedz
# Data loaded into files
# ssawa1_Temp_silnika_zelazo
# Data loaded into files
# ssawa1_Z555tC_drgania_lozyskaC
# Data loaded into files
# ssawa1_Z555tD_drgania_lozyskaD
# Data loaded into files
# ssawa2_F561t_przeplyw_oleju_w_lozysku_D
# Data loaded into files
# ssawa2_F562t_przeplyw_oleju_w_lozysku_C
# Data loaded into files
# ssawa2_F563_1t_przepl_oleju_loz_B_silnika
# Data loaded into files
# ssawa2_F563_2t_przepl_oleju_loz_A_silnika
# Data loaded into files
# ssawa2_Otwarcie_klapy
# Data loaded into files
# ssawa2_P521C_cis_oleju_w_lozysku_C
# Data loaded into files
# ssawa2_P521D_cis_oleju_w_lozysku_D
# Data loaded into files
# ssawa2_P556a_cis_oleju_w_obiegu
# Data loaded into files
# Ssawa2_Podcisnienie_przed_ssawa
# Data loaded into files
# ssawa2_Prad_silnika
# Data loaded into files
# ssawa2_Prad_wzbudzenia
# Data loaded into files
# ssawa2_T480t1_temp_w_loz_A_silnika
# Data loaded into files
# ssawa2_T480t2_temp_w_loz_B_silnika
# Data loaded into files
# ssawa2_T480t3_temp_pow_chlodz_silnik_wlot
# Data loaded into files
# ssawa2_T480t4_temp_pow_chlodz_silnik_wlot
# Data loaded into files
# ssawa2_T480t5_temp_pow_chlodz_silnik_wylot
# Data loaded into files
# ssawa2_T480t6_temp_pow_chlodz_silnik_wylot
# Data loaded into files
# ssawa2_T480t7_temp_wody_chlodz_zasil
# Data loaded into files
# ssawa2_T480t8_temp_wody_chlodz_powrot
# Data loaded into files
# ssawa2_T552_temp_oleju_zbiornik
# Data loaded into files
# ssawa2_T558t_temp_oleju_w_obiegu
# Data loaded into files
# ssawa2_T559tC_temp_w_lozysku_C
# Data loaded into files
# ssawa2_T559tD_temp_w_lozysku_D
# Data loaded into files
# ssawa2_Temp_silnika_miedz
# Data loaded into files
# ssawa2_Temp_silnika_zelazo
# Data loaded into files
# ssawa2_Z555tC_drgania_lozyska_C
# Data loaded into files
# ssawa2_Z555tD_drgania_lozyska_D
# Data loaded into files
# T1_Beben_Poziom
# Data loaded into files
# T1_cisnGazuPoReg
# Data loaded into files
# T1_CO_na_chlodni
# Data loaded into files
# T1_iloscGazu
# Data loaded into files
# T1_OCtempwlot
# Data loaded into files
# T1_OCtempwylot
# Data loaded into files
# T1_OCtprzeplpow
# Data loaded into files
# T1_podc-kolektorL
# Data loaded into files
# T1_podc-kolektorP
# Data loaded into files
# T1_podc-komora10P
# Data loaded into files
# T1_podc-komora11L
# Data loaded into files
# T1_podc-komora12P
# Data loaded into files
# T1_podc-komora13L
# Data loaded into files
# T1_podc-komora14L
# Data loaded into files
# T1_podc-komora15P
# Data loaded into files
# T1_podc-komora16L
# Data loaded into files
# T1_podc-komora17P
# Data loaded into files
# T1_podc-komora18L
# Data loaded into files
# T1_podc-komora19P
# Data loaded into files
# T1_podc-komora1L
# Data loaded into files
# T1_podc-komora20L
# Data loaded into files
# T1_podc-komora21P
# Data loaded into files
# T1_podc-komora22L
# Data loaded into files
# T1_podc-komora23P
# Data loaded into files
# T1_podc-komora24L
# Data loaded into files
# T1_podc-komora25P
# Data loaded into files
# T1_podc-komora26L
# Data loaded into files
# T1_podc-komora27P
# Data loaded into files
# T1_podc-komora2P
# Data loaded into files
# T1_podc-komora3L
# Data loaded into files
# T1_podc-komora4P
# Data loaded into files
# T1_podc-komora5L
# Data loaded into files
# T1_podc-komora6P
# Data loaded into files
# T1_podc-komora7L
# Data loaded into files
# T1_podc-komora8P
# Data loaded into files
# T1_podc-komora9L
# Data loaded into files
# T1_Predkosc_tasmy
# Data loaded into files
# T1_przMieszGrudk1
# Data loaded into files
# T1_przMieszGrudk2
# Data loaded into files
# T1_przWodyGrud1
# Data loaded into files
# T1_przWodyGrud2
# Data loaded into files
# T1_PT128_wydajnosc
# Data loaded into files
# T1_Temperatura_PT128
# Data loaded into files
# T1_temp-kolektorL
# Data loaded into files
# T1_temp-kolektorP
# Data loaded into files
# T1_temp-komora10P
# Data loaded into files
# T1_temp-komora11L
# Data loaded into files
# T1_temp-komora12P
# Data loaded into files
# T1_temp-komora13L
# Data loaded into files
# T1_temp-komora14L
# Data loaded into files
# T1_temp-komora15P
# Data loaded into files
# T1_temp-komora16L
# Data loaded into files
# T1_temp-komora17P
# Data loaded into files
# T1_temp-komora18L
# Data loaded into files
# T1_temp-komora19P
# Data loaded into files
# T1_temp-komora1L
# Data loaded into files
# T1_temp-komora20L
# Data loaded into files
# T1_temp-komora21P
# Data loaded into files
# T1_temp-komora22L
# Data loaded into files
# T1_temp-komora23P
# Data loaded into files
# T1_temp-komora24L
# Data loaded into files
# T1_temp-komora25P
# Data loaded into files
# T1_temp-komora26L
# Data loaded into files
# T1_temp-komora27P
# Data loaded into files
# T1_temp-komora2P
# Data loaded into files
# T1_temp-komora3L
# Data loaded into files
# T1_temp-komora4P
# Data loaded into files
# T1_temp-komora5L
# Data loaded into files
# T1_temp-komora6P
# Data loaded into files
# T1_temp-komora7L
# Data loaded into files
# T1_temp-komora8P
# Data loaded into files
# T1_temp-komora9L
# Data loaded into files
# T1_tempPieca
# Data loaded into files
# T1_TempSpiekuzaChlodnia
# Data loaded into files
# T1_Wapno_PrzeplywWody
# Data loaded into files
# T1_Wapno_wydajnosc
# Data loaded into files
# T1_WT15_ruda_wydajnosc
# Data loaded into files
# T1_WT16_wydajnosc
# Data loaded into files
# T1_WT17_wydajnosc
# Data loaded into files
# T1_wydWaga1
# Data loaded into files
# T1_wydWaga10
# Data loaded into files
# T1_wydWaga11
# Data loaded into files
# T1_wydWaga12
# Data loaded into files
# T1_wydWaga13
# Data loaded into files
# T1_wydWaga15
# Data loaded into files
# T1_wydWaga2
# Data loaded into files
# T1_wydWaga3
# Data loaded into files
# T1_wydWaga4
# Data loaded into files
# T1_wydWaga5
# Data loaded into files
# T1_wydWaga6
# Data loaded into files
# T1_wydWaga7
# Data loaded into files
# T1_wydWaga8
# Data loaded into files
# T1_wydWaga9
# Data loaded into files
# T1_ZB7_zapelnienie
# Data loaded into files
# T1_ZBBufor_Sortownia_zapelnienie
# Data loaded into files
# T1_ZBPods_ciezar
# Data loaded into files
# Wall time: 3h 13min 5s

# %%
df3
# Out:
#                timestampCol     value
# 0       2020-01-01 00:00:10  3.538443
# 1       2020-01-01 00:00:20  3.504537
# 2       2020-01-01 00:00:30  3.470630
# 3       2020-01-01 00:00:40  3.436724
# 4       2020-01-01 00:00:50  3.412992
# ...                     ...       ...
# 1588576 2020-12-17 22:47:20  3.935998
# 1588577 2020-12-17 22:47:30  3.915186
# 1588578 2020-12-17 22:47:40  3.894375
# 1588579 2020-12-17 22:47:50  3.873563
# 1588580 2020-12-17 22:48:00  3.852751
#
# [1588581 rows x 2 columns]

# %%
df3
# Out:
#                timestampCol     value            timestamp
# 0       2020-01-01 00:00:10  3.538443  2020-01-01 00:00:10
# 1       2020-01-01 00:00:20  3.504537  2020-01-01 00:00:20
# 2       2020-01-01 00:00:30  3.470630  2020-01-01 00:00:30
# 3       2020-01-01 00:00:40  3.436724  2020-01-01 00:00:40
# 4       2020-01-01 00:00:50  3.412992  2020-01-01 00:00:50
# ...                     ...       ...                  ...
# 1588576 2020-12-17 22:47:20  3.935998  2020-12-17 22:47:20
# 1588577 2020-12-17 22:47:30  3.915186  2020-12-17 22:47:30
# 1588578 2020-12-17 22:47:40  3.894375  2020-12-17 22:47:40
# 1588579 2020-12-17 22:47:50  3.873563  2020-12-17 22:47:50
# 1588580 2020-12-17 22:48:00  3.852751  2020-12-17 22:48:00
#
# [1588581 rows x 3 columns]

# %%
from os import listdir
from os.path import isfile, join
mypath = r"C:\Users\a0730244\Documents\AzureBlobByDay"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
emptyNameList = []
i = 0;

# %%
for file in onlyfiles:
    emptyNameList.append('series_'+str(i)+'.csv')
    i = i + 1

# %%
emptyNameList
# Out:
# ['series_0.csv',
#  'series_1.csv',
#  'series_2.csv',
#  'series_3.csv',
#  'series_4.csv',
#  'series_5.csv',
#  'series_6.csv',
#  'series_7.csv',
#  'series_8.csv',
#  'series_9.csv',
#  'series_10.csv',
#  'series_11.csv',
#  'series_12.csv',
#  'series_13.csv',
#  'series_14.csv',
#  'series_15.csv',
#  'series_16.csv',
#  'series_17.csv',
#  'series_18.csv',
#  'series_19.csv',
#  'series_20.csv',
#  'series_21.csv',
#  'series_22.csv',
#  'series_23.csv',
#  'series_24.csv',
#  'series_25.csv',
#  'series_26.csv',
#  'series_27.csv',
#  'series_28.csv',
#  'series_29.csv',
#  'series_30.csv',
#  'series_31.csv',
#  'series_32.csv',
#  'series_33.csv',
#  'series_34.csv',
#  'series_35.csv',
#  'series_36.csv',
#  'series_37.csv',
#  'series_38.csv',
#  'series_39.csv',
#  'series_40.csv',
#  'series_41.csv',
#  'series_42.csv',
#  'series_43.csv',
#  'series_44.csv',
#  'series_45.csv',
#  'series_46.csv',
#  'series_47.csv',
#  'series_48.csv',
#  'series_49.csv',
#  'series_50.csv',
#  'series_51.csv',
#  'series_52.csv',
#  'series_53.csv',
#  'series_54.csv',
#  'series_55.csv',
#  'series_56.csv',
#  'series_57.csv',
#  'series_58.csv',
#  'series_59.csv',
#  'series_60.csv',
#  'series_61.csv',
#  'series_62.csv',
#  'series_63.csv',
#  'series_64.csv',
#  'series_65.csv',
#  'series_66.csv',
#  'series_67.csv',
#  'series_68.csv',
#  'series_69.csv',
#  'series_70.csv',
#  'series_71.csv',
#  'series_72.csv',
#  'series_73.csv',
#  'series_74.csv',
#  'series_75.csv',
#  'series_76.csv',
#  'series_77.csv',
#  'series_78.csv',
#  'series_79.csv',
#  'series_80.csv',
#  'series_81.csv',
#  'series_82.csv',
#  'series_83.csv',
#  'series_84.csv',
#  'series_85.csv',
#  'series_86.csv',
#  'series_87.csv',
#  'series_88.csv',
#  'series_89.csv',
#  'series_90.csv',
#  'series_91.csv',
#  'series_92.csv',
#  'series_93.csv',
#  'series_94.csv',
#  'series_95.csv',
#  'series_96.csv',
#  'series_97.csv',
#  'series_98.csv',
#  'series_99.csv',
#  'series_100.csv',
#  'series_101.csv',
#  'series_102.csv',
#  'series_103.csv',
#  'series_104.csv',
#  'series_105.csv',
#  'series_106.csv',
#  'series_107.csv',
#  'series_108.csv',
#  'series_109.csv',
#  'series_110.csv',
#  'series_111.csv',
#  'series_112.csv',
#  'series_113.csv',
#  'series_114.csv',
#  'series_115.csv',
#  'series_116.csv',
#  'series_117.csv',
#  'series_118.csv',
#  'series_119.csv',
#  'series_120.csv',
#  'series_121.csv',
#  'series_122.csv',
#  'series_123.csv',
#  'series_124.csv',
#  'series_125.csv',
#  'series_126.csv',
#  'series_127.csv',
#  'series_128.csv',
#  'series_129.csv',
#  'series_130.csv',
#  'series_131.csv',
#  'series_132.csv',
#  'series_133.csv',
#  'series_134.csv',
#  'series_135.csv',
#  'series_136.csv',
#  'series_137.csv',
#  'series_138.csv',
#  'series_139.csv',
#  'series_140.csv',
#  'series_141.csv',
#  'series_142.csv',
#  'series_143.csv',
#  'series_144.csv',
#  'series_145.csv',
#  'series_146.csv',
#  'series_147.csv',
#  'series_148.csv',
#  'series_149.csv',
#  'series_150.csv',
#  'series_151.csv',
#  'series_152.csv',
#  'series_153.csv',
#  'series_154.csv',
#  'series_155.csv',
#  'series_156.csv',
#  'series_157.csv',
#  'series_158.csv',
#  'series_159.csv',
#  'series_160.csv',
#  'series_161.csv',
#  'series_162.csv',
#  'series_163.csv',
#  'series_164.csv']
